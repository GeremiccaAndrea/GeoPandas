# %% [markdown]
# <a href="https://colab.research.google.com/github/GeremiccaAndrea/GeoPandas/blob/main/GeoPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas

# %%
# %matplotlib inline

import pandas as pd
import geopandas

# %%
countries = geopandas.read_file("https://github.com/jorisvandenbossche/geopandas-tutorial/blob/main/data/ne_110m_admin_0_countries.zip?raw=true")
countries
# Out:
#     iso_a3                  name      continent     pop_est  gdp_md_est  \
# 0      AFG           Afghanistan           Asia  34124811.0     64080.0
# 1      AGO                Angola         Africa  29310273.0    189000.0
# 2      ALB               Albania         Europe   3047987.0     33900.0
# 3      ARE  United Arab Emirates           Asia   6072475.0    667200.0
# 4      ARG             Argentina  South America  44293293.0    879400.0
# ..     ...                   ...            ...         ...         ...
# 172    VUT               Vanuatu        Oceania    282814.0       723.0
# 173    YEM                 Yemen           Asia  28036829.0     73450.0
# 174    ZAF          South Africa         Africa  54841552.0    739100.0
# 175    ZMB                Zambia         Africa  15972000.0     65170.0
# 176    ZWE              Zimbabwe         Africa  13805084.0     28330.0
#
#                                               geometry
# ...

# %%
countries.plot()
# asse x longitudine da -180 a +180 (asse orizzontale)
# asse y altitudine da -90 a +90 (asse verticale)

# %%
#prende tutte le nazioni africane
africa = countries[countries['continent'] == 'Africa']
africa
# Out:
#     iso_a3                  name continent      pop_est  gdp_md_est  \
# 1      AGO                Angola    Africa   29310273.0    189000.0
# 11     BDI               Burundi    Africa   11466756.0      7892.0
# 13     BEN                 Benin    Africa   11038805.0     24310.0
# 14     BFA          Burkina Faso    Africa   20107509.0     32990.0
# 25     BWA              Botswana    Africa    2214858.0     35900.0
# 26     CAF  Central African Rep.    Africa    5625118.0      3206.0
# 31     CIV         Côte d'Ivoire    Africa   24184810.0     87120.0
# 32     CMR              Cameroon    Africa   24994885.0     77240.0
# 33     COD       Dem. Rep. Congo    Africa   83301151.0     66010.0
# 34     COG                 Congo    Africa    4954674.0     30270.0
# 42     DJI              Djibouti    Africa     865267.0      3345.0
# 45     DZA               Algeria    Africa   40969443.0    609400.0
# 47     EGY                 Egypt    Africa   97041072.0   1105000.0
# ...

# %%
africa.plot()

# %%
countries.geometry #prende solo la colonna geometria
# Out:
# 0      POLYGON ((61.21082 35.65007, 62.23065 35.27066...
# 1      MULTIPOLYGON (((23.90415 -11.72228, 24.07991 -...
# 2      POLYGON ((21.02004 40.84273, 20.99999 40.58000...
# 3      POLYGON ((51.57952 24.24550, 51.75744 24.29407...
# 4      MULTIPOLYGON (((-66.95992 -54.89681, -67.56244...
#                              ...
# 172    MULTIPOLYGON (((167.84488 -16.46633, 167.51518...
# 173    POLYGON ((52.00001 19.00000, 52.78218 17.34974...
# 174    POLYGON ((19.89577 -24.76779, 20.16573 -24.917...
# 175    POLYGON ((23.21505 -17.52312, 22.56248 -16.898...
# 176    POLYGON ((29.43219 -22.09131, 28.79466 -21.639...
# Name: geometry, Length: 177, dtype: geometry

# %%
countries[countries['name'] == 'Italy'].area #calcolo l'area
# Out:
# <ipython-input-22-2b7425687aa9>:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   countries[countries['name'] == 'Italy'].area
# 79    34.685652
# dtype: float64

# %%
cities = geopandas.read_file("https://github.com/jorisvandenbossche/geopandas-tutorial/blob/main/data/ne_110m_populated_places.zip?raw=true")
cities
# Out:
#                name                     geometry
# 0      Vatican City    POINT (12.45339 41.90328)
# 1        San Marino    POINT (12.44177 43.93610)
# 2             Vaduz     POINT (9.51667 47.13372)
# 3           Lobamba   POINT (31.20000 -26.46667)
# 4        Luxembourg     POINT (6.13000 49.61166)
# ..              ...                          ...
# 238  Rio de Janeiro  POINT (-43.22697 -22.92308)
# 239       São Paulo  POINT (-46.62697 -23.55673)
# 240          Sydney  POINT (151.18323 -33.91807)
# 241       Singapore    POINT (103.85387 1.29498)
# 242       Hong Kong   POINT (114.18306 22.30693)
#
# [243 rows x 2 columns]

# %%
ax = countries.plot(edgecolor='k', facecolor='none', figsize=(15, 10))
cities.plot(ax=ax, color='red')
ax.set(xlim=(-20, 60), ylim=(-40, 40)) #coordinate che ti permettono di vedere l'Africa
# Out:
# [(-40.0, 40.0), (-20.0, 60.0)]

# %%
ax = countries.plot(edgecolor='k', facecolor='none', figsize=(15, 10))
cities.plot(ax=ax, color='red')
ax.set(xlim=(5, 20), ylim=(35, 48))
# Out:
# [(35.0, 48.0), (5.0, 20.0)]

# %% [markdown]
# # Esercizio

# %%
stations = geopandas.read_file('https://github.com/jorisvandenbossche/geopandas-tutorial/blob/main/data/paris_bike_stations_mercator.gpkg?raw=true')
stations
# Out:
# WARNING:fiona._env:File /vsimem/a3b1a1713d1047e7ba2f2a4eb8c7f916 has GPKG application_id, but non conformant file extension
#                                         name  bike_stands  available_bikes  \
# 0                     14002 - RASPAIL QUINET           44                4
# 1        20503 - COURS DE VINCENNES PYRÉNÉES           21                3
# 2                   20011 - PYRÉNÉES-DAGORNO           21                0
# 3              31008 - VINCENNES (MONTREUIL)           56                0
# 4                43006 - MINIMES (VINCENNES)           28               27
# ...                                      ...          ...              ...
# 1221                       12011 - CHARENTON           36               35
# 1222             13110 - MOULIN DE LA POINTE           22                4
# 1223                   07006 - QUAI VOLTAIRE           32               25
# 1224  21311 - GAMBETTA (ISSY LES MOULINEAUX)           55               47
# ...

# %%
stations.plot()

# %%
# !pip install contextily

# %%
import contextily

# %%
ax = stations.plot(figsize=(12,6), markersize=5)
contextily.add_basemap(ax)

# %%
#linea orizzontale = posti, linea verticale numero di stazioni
stations['bike_stands'].hist() #hist = istogramma

# %%
ax = stations.plot(figsize=(15, 10), column='available_bikes', legend=True,  markersize=5) 
contextily.add_basemap(ax)

# %%
districts = geopandas.read_file("https://raw.githubusercontent.com/jorisvandenbossche/geopandas-tutorial/main/data/paris_districts_utm.geojson")
districts
# Out:
#     id           district_name  population  \
# 0    1  St-Germain-l'Auxerrois        1672
# 1    2                  Halles        8984
# 2    3            Palais-Royal        3195
# 3    4           Place-Vendôme        3044
# 4    5                 Gaillon        1345
# ..  ..                     ...         ...
# 75  76                  Combat       38988
# 76  77              Belleville       35773
# 77  78           Saint-Fargeau       42087
# 78  79           Père-Lachaise       42332
# 79  80                Charonne       62901
#
#                                              geometry
# 0   POLYGON ((451922.133 5411438.484, 451922.080 5...
# 1   POLYGON ((452278.419 5412160.893, 452192.407 5...
# 2   POLYGON ((451553.806 5412340.522, 451528.058 5...
# 3   POLYGON ((451004.908 5412654.095, 450960.640 5...
# 4   POLYGON ((451328.752 5412991.278, 451294.721 5...
# ..                                                ...
# 75  POLYGON ((455155.128 5414359.413, 455239.337 5...
# ...

# %%
districts.plot()

# %%
ax = districts.plot()
contextily.add_basemap(ax)

# %%
districts.geometry.area
# Out:
# 0     8.685379e+05
# 1     4.122371e+05
# 2     2.735494e+05
# 3     2.693111e+05
# 4     1.879097e+05
#           ...
# 75    1.294254e+06
# 76    8.061191e+05
# 77    1.486139e+06
# 78    1.598127e+06
# 79    2.089783e+06
# Length: 80, dtype: float64

# %%
districts['area'] = districts.geometry.area / 1e6
districts
# Out:
#     id           district_name  population  \
# 0    1  St-Germain-l'Auxerrois        1672
# 1    2                  Halles        8984
# 2    3            Palais-Royal        3195
# 3    4           Place-Vendôme        3044
# 4    5                 Gaillon        1345
# ..  ..                     ...         ...
# 75  76                  Combat       38988
# 76  77              Belleville       35773
# 77  78           Saint-Fargeau       42087
# 78  79           Père-Lachaise       42332
# 79  80                Charonne       62901
#
#                                              geometry      area
# 0   POLYGON ((451922.133 5411438.484, 451922.080 5...  0.868538
# 1   POLYGON ((452278.419 5412160.893, 452192.407 5...  0.412237
# 2   POLYGON ((451553.806 5412340.522, 451528.058 5...  0.273549
# 3   POLYGON ((451004.908 5412654.095, 450960.640 5...  0.269311
# 4   POLYGON ((451328.752 5412991.278, 451294.721 5...  0.187910
# ...

# %%
districts['population_density'] = districts['population'] / districts.geometry.area * 10**6
districts
# Out:
#     id           district_name  population  \
# 0    1  St-Germain-l'Auxerrois        1672
# 1    2                  Halles        8984
# 2    3            Palais-Royal        3195
# 3    4           Place-Vendôme        3044
# 4    5                 Gaillon        1345
# ..  ..                     ...         ...
# 75  76                  Combat       38988
# 76  77              Belleville       35773
# 77  78           Saint-Fargeau       42087
# 78  79           Père-Lachaise       42332
# 79  80                Charonne       62901
#
#                                              geometry      area  \
# 0   POLYGON ((451922.133 5411438.484, 451922.080 5...  0.868538
# 1   POLYGON ((452278.419 5412160.893, 452192.407 5...  0.412237
# 2   POLYGON ((451553.806 5412340.522, 451528.058 5...  0.273549
# 3   POLYGON ((451004.908 5412654.095, 450960.640 5...  0.269311
# 4   POLYGON ((451328.752 5412991.278, 451294.721 5...  0.187910
# ...

# %%
districts.plot(column='population_density', figsize=(12, 6), legend=True)

# %%
stations = geopandas.read_file('https://github.com/jorisvandenbossche/geopandas-tutorial/blob/main/data/paris_bike_stations_mercator.gpkg?raw=true')
stations
# Out:
# WARNING:fiona._env:File /vsimem/35cd7d792daa46438428899a2390a744 has GPKG application_id, but non conformant file extension
#                                         name  bike_stands  available_bikes  \
# 0                     14002 - RASPAIL QUINET           44                4
# 1        20503 - COURS DE VINCENNES PYRÉNÉES           21                3
# 2                   20011 - PYRÉNÉES-DAGORNO           21                0
# 3              31008 - VINCENNES (MONTREUIL)           56                0
# 4                43006 - MINIMES (VINCENNES)           28               27
# ...                                      ...          ...              ...
# 1221                       12011 - CHARENTON           36               35
# 1222             13110 - MOULIN DE LA POINTE           22                4
# 1223                   07006 - QUAI VOLTAIRE           32               25
# 1224  21311 - GAMBETTA (ISSY LES MOULINEAUX)           55               47
# ...

# %%
type(stations)
# Out:
# geopandas.geodataframe.GeoDataFrame
